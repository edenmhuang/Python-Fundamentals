# %% [markdown]
# # Lab 1 - Comp 122 - Fall 2022

# %% [markdown]
# 09/06/2022, 12/25/2022

# %%
#import the math module, which contains features for working with mathmatics
import math

# %%
#print value of pi
print(math.pi)

#print Square Root of 45, sqrt()
print(math.sqrt(45))

#Find the area of a circle with a radius of 2, A = pi(r^2)
r = 2
area = math.pi * r**2
print(area)
# Out:
# 3.141592653589793
# 6.708203932499369
# 12.566370614359172

# %% [markdown]
# # Functions

# %% [markdown]
# Define a function that accepts 3 values and return its sum, subtraction and multiplication.

# %%
def num(a,b,c):
    num1 = a+b+c
    num2 = a-b-c
    num3 = a*b*c
    return(num1, num2, num3)
num(1,2,3)
# Out:
# (6, -4, 6)

# %% [markdown]
# # Assign and Modify Variables

# %% [markdown]
# Now it's your turn to work with variables. The comments in this section (the lines that begin with #) have instructions for creating and modifying variables.
# After each comment write a line of ode that implements the instruction.
#
# Note that this code uses scientific notation: https://en.wikipedia.org/wiki/Scientific_notation to define large numbers. 4.44e8 is equal to 4.445 * 10 ** 8 <br>
# which is equal to 444500000.0

# %%
#The current volume of a water reservoir (in cubic metres)
reservoir_volume = 4.445e8
#The amount of rainfall from a storm (in cubic metres)
rainfall = 5e6

#decrease the rainfall variable by 20% to account for runoff
rainfall2 = rainfall * 0.2
rainfall3 = rainfall - rainfall2
print(rainfall3, 'is the rainfall decreased by 20%')
#rainfall2 is 20% of 5e6
#rainfall3 is 5e6 - 1e6

#add the rainfall variable to the reservoir_volume variable
print(rainfall3 + reservoir_volume, 'is rainfall plus reservoir_volume')

#increase reservoir_volume by 15% to account for stormwater that flows into the reservoir in the dats following the storm
reservoir_volume2 = reservoir_volume * 0.15
reservoir_volume3 = reservoir_volume + reservoir_volume2

#decrease reservoir_volume by 15% to account for evaporation
reservoir_volume4 = reservoir_volume - reservoir_volume2

#subtract 2.5e5 cubic metres from reservoir_volume to account for water that's piped to arid regions.
reservoir_volume5 = reservoir_volume - 2.5e5

#print the new vlue of the reservoir_volume variable
print(reservoir_volume5, 'is new reservoir_volume')
# Out:
# 4000000.0 is the rainfall decreased by 20%
# 448500000.0 is rainfall plus reservoir_volume
# 444250000.0 is new reservoir_volume

# %% [markdown]
# # Booleans, Comparison Operators, and Logical Operators

# %% [markdown]
# How George Boole's zeros and ones changed the world:
# https://www.irishtimes.com/news/science/how-george-boole-s-zeroes-and-ones-changed-the-world-1.2014673#:~:text=The%20real%20value%20of%20Boole%27s,be%20drawn%20by%20algebraic%20calculations.

# %% [markdown]
# The bool data type holds one of the values True or False, which are often encoded as 1 or 0, respectively. <br>
# There are 6 comparision operators that common to see in order to obtain a bool value:

# %% [markdown]
# ![comparison_operators.png](attachment:comparison_operators.png)

# %% [markdown]
# # Which is denser, New York City or San Francisco?

# %% [markdown]
# Try comparison operators! This code calculates the popoulation densities of New York City and San Francisco.<br>
# Write code to compare these densities. Is the population of San Francisco more dense than that of New York?<br>
# Print True if it is and False if not.

# %%
sf_population, sf_area = 864816, 48.69
ny_population, ny_area = 8175133, 302.6

san_francisco_pop_density = sf_population/sf_area
new_york_pop_density = ny_population/ny_area

#Write code that prints True if San Fracisco is denser than New York City, and False otherwise
if san_francisco_pop_density > new_york_pop_density:
    print(True)
else:
    print(False)
# Out:
# False

# %% [markdown]
# # Strings

# %% [markdown]
# Strings in Python are shown as the variable type str. You can define a string with either double quotes" or single quotes '. <br>
# If the string you are creating actually has one of these two values in it, then you need to be careful to assure your code doesn't give an errot.

# %%
my_string = 'this is a string!'
my_string2 = "this is also a string!!!"

# %% [markdown]
# You can also include a \ in your string to be able to include one of these quotes:

# %%
this_string = 'Alan\'s bike is in the garage.'
print(this_string)
# Out:
# Alan's bike is in the garage.

# %% [markdown]
# Unlike the other daa types you have seen so far, you can also index into strings. <br>
# Notice Python uses 0 indexing.

# %%
my_string[0]
# Out:
# 't'

# %%
my_string[2]
# Out:
# 'i'

# %% [markdown]
# # The len() function

# %% [markdown]
# len() is the built-in Python function that returns the length of an object, like a string. The length of a string is the number of characters in the string. <br>
# This will always be an integer.<br>
# There is an exaple above, but here's another one:

# %%
print(len('abcabcabc') / len('abc'))
# Out:
# 3.0

# %% [markdown]
# The line of code in the following cell will cause a SyntaxError, thanks to the misuse of quotation marks. First run it with Test Run to view the error message. Then resolve the problem so that the quote is correctly assigned to the variable best_ford_quote.

# %%
best_ford_quote = 'Whether you think you can, or you think you can\'t you\'re right.'
print(best_ford_quote)
# Out:
# Whether you think you can, or you think you can't you're right.

# %% [markdown]
# # Write a Servor Log Message

# %% [markdown]
# In this programming cell, you're going to use what you've learned about strings to write a logging message for a server. You'll be provided with example data for a user, the time of their visit and the site they accessed. You should use the variables provided and the techniques you've learned to print a log message likfe this one (with username, url, and timestamp replaced with values from the appropriate variables):
#
# Alan accessed the site https://stackoverflow.com/questions/32 at 19:20.

# %%
username ='"Alan'
timestamp = '19:20."'
url = "https://stackoverflow.com/questions/32"
print(username, 'accessed the site', url, 'at', timestamp)
# print a log message using the variables above.
# The message should have the same format as this one:
# "Alen accessed the site https://stackoverflow.com/questions/32 at 19:20."
# Out:
# "Alan accessed the site https://stackoverflow.com/questions/32 at 19:20."

# %% [markdown]
# Use strong concatenation and the len() function to find the length of a certain movie star's actual full name. Store that length in the name_length variable. Don't forget there are spaces in between the different parts of a name!

# %%
given_name = "William"
middle_name = "Bradley"
family_name = "Pitt"

name_length = given_name + middle_name + family_name
#calculate how long this name is
print(name_length)
print(len(name_length))
#Now we check to make sure that the name fits within the driving license character limit
driving_license_character_limit = 20
print(len(name_length) <= driving_license_character_limit)
# Out:
# WilliamBradleyPitt
# 18
# True
