# %% [markdown]
#   # <center> Comp 122 - Fall 2022 <br><br>Project 1: web crawler 1.1 <br><br> Lists - Functions - Strings - Loops</center>

# %% [markdown]
# This project aims to turn some of the magic of the search engine into something a bit more understandable. The biggest goal is to learn more about computer science. Computer science is about solving problems, like building a search engine, by breaking them into smaller pieces and then precisely and mechanically describing a sequence of steps that you can use to solve each part. And those steps can be executed by a computer. For the search engine, the three main pieces are:<br>
# <ul>
#     <li>Finding data by crawling web pages</li>
# <li>Building an index to respond quickly to search queries</li>
# <li>Ranking pages to get the best result for a given query</li>
# </ul>
# <br>
# In this project, we will not get into everything that you need to build a search engine as powerful as Google, but we will cover the main ideas and learn a lot about computer science along the way.

# %% [markdown]
# # What you need to know to complete this project

# %% [markdown]
# <b>- Lists are used to store multiple items in a single variable.</b>
# https://docs.python.org/3/tutorial/datastructures.html
#
# Lists are one of 4 built-in data types in Python used to store collections of data, the other 3 are Tuple, Set, and Dictionary, all with different qualities and usage.

# %% [markdown]
# A <b>function</b> is a block of code which only runs when it is called. You can pass data, known as parameters, into a function. A function can return data as a result.

# %% [markdown]
# <b>- Strings</b> in python are surrounded by either single quotation marks, or double quotation marks.
# <b>Strings are Arrays</b> Like many other popular programming languages, strings in Python are arrays of bytes representing unicode characters. However, Python does not have a character data type, a single character is simply a string with a length of 1. Square brackets [ ]  can be used to access elements of the string.
# https://docs.python.org/3/tutorial/introduction.html#strings

# %% [markdown]
# <b>- Python For Loops</b> A <b>for</b> loop is used for iterating over a sequence (that is either a list, a tuple, a dictionary, a set, or a string).
# This is less like the for keyword in other programming languages, and works more like an iterator method as found in other object-orientated programming languages.
# With the for loop we can execute a set of statements, once for each item in a list.
# https://docs.python.org/3/tutorial/controlflow.html?highlight=loop

# %% [markdown]
# # Extracting / printing Links

# %% [markdown]
# 1) Write Python code that assigns to the variable url, a string that is the value of the first URL that appears in a
# link tag in the string page. Your code should print https://websmart.smccd.edu

# %%
#page = contents of a web page on https://webschedule.smccd.edu/course/202208/97582
page = ('  <div class="container block">'
                '<div class="pull-left">'
                   ' <div class="btn-group pull-left">'
                       ' <button type="button" class="btn btn-primary btn-sm dropdown-toggle" data-toggle="dropdown">'
                          '  Change Site&nbsp;&nbsp;<i class="fa fa-caret-down"></i>'
                        '</button>'
                       ' <ul class="dropdown-menu" role="menu">'
                          '  <li><a href="https://websmart.smccd.edu" role="listitem"><i class="fa fa-lg fa-gear"></i>&nbsp;&nbsp;WebSMART</a></li>'
                          '  <li><a href="https://smccd.instructure.com/" role="listitem"><i class="fa fa-lg fa-globe"></i>&nbsp;&nbsp;Canvas</a></li>'
                          '  <li><a href="https://my.smccd.edu" role="listitem"><i class="fa fa-lg fa-envelope"></i>&nbsp;&nbsp;My.SMCCD</a></li>'
                          '  <li><a href="https://smccd.edu/portal" role="listitem"><i class="fa fa-lg fa-columns"></i>&nbsp;&nbsp;Portal</a></li>'
                          '  <li><a href="https://webschedule.smccd.edu" role="listitem"><i class="fa fa-lg fa-table"></i>&nbsp;&nbsp;WebSchedule</a></li>'
                          '  <li class="divider"></li>'
                          '  <li class="li-csm" role="listitem"><a href="https://collegeofsanmateo.edu"><i class="fa fa-lg fa-university"></i>&nbsp;&nbsp;College of San Mateo</a></li>'
                          '  <li class="li-can" role="listitem"><a href="https://canadacollege.edu"><i class="fa fa-lg fa-university"></i>&nbsp;&nbsp;Cañada College</a></li>'
                          '  <li class="li-sky" role="listitem"><a href="https://skylinecollege.edu"><i class="fa fa-lg fa-university"></i>&nbsp;&nbsp;Skyline College</a></li>'
                      '  </ul>'
                   ' </div>'
                   ' <div class="pull-left hidden-xs" style="margin-top:3px; padding-left: 3px"> | SMCCCD</div>'
               ' </div>')

# %%
url = page[page.find('<a href="') + 9: page.find('>', page.find('<a href="')) - 17]
print(url)
# Out:
# https://websmart.smccd.edu

# %% [markdown]
# 2) Write Python code to prints all the URL that appears in a link tag in the string page. Your code should print:<br>
# https://websmart.smccd.edu<br>
# https://smccd.instructure.com/<br>
# https://my.smccd.edu<br>
# https://smccd.edu/portal<br>
# https://webschedule.smccd.edu<br>
# https://collegeofsanmateo.edu<br>
# https://canadacollege.edu<br>
# https://skylinecollege.edu

# %%
while '<a href="' in page:
    if page.find('<a href="') == -1: 
        break
    else:
        start = page.find('<a href="') + len('<a href="')
        end = page.find('"', start)
        url = page[start:end]
        page = page[end:]
    print(url)
# Out:
# https://websmart.smccd.edu
# https://smccd.instructure.com/
# https://my.smccd.edu
# https://smccd.edu/portal
# https://webschedule.smccd.edu
# https://collegeofsanmateo.edu
# https://canadacollege.edu
# https://skylinecollege.edu

# %% [markdown]
# 3) Write a function <b>find_next_point.</b> This function should return a link as well as the end position of the link. Your task is to modify the function to detect the case when no link is found. If there is no link tag, the function should return: None, 0

# %%
def find_next_point(page):
    while True:
        if '<a href="' in page:
            start = page.find('<a href="') + len('<a href="')
            end = page.find('"', start)
            url = page[start:end]
            page = page[end:]
            return(url, end)
        else:
            return None, 0

# %%
find_next_point(page)
# Out:
# ('https://websmart.smccd.edu', 327)

# %% [markdown]
# 4) Write a function <b>print_all_url</b>. This function must keep going until there are no more url to print. Think about looping forever (set while loop condition) until there are no more links (i.e. else:). What do you do when there are no more links (body of else: condition)?<br>
# Hint: <b>print_all_url</b> should call <b>find_next_point</b>

# %%
def print_all_url(page):
    link, last = find_next_point(page)
    page = page[last:]
    if last == 0:
        None
    else:
        print(link)
        print_all_url(page)
    
print_all_url(page)
# Out:
# https://websmart.smccd.edu
# https://smccd.instructure.com/
# https://my.smccd.edu
# https://smccd.edu/portal
# https://webschedule.smccd.edu
# https://collegeofsanmateo.edu
# https://canadacollege.edu
# https://skylinecollege.edu

# %% [markdown]
# 5) Write a function <b>get_all_url.</b> This function must store all the URLs from the page to a list. Your function should return a list of all the URLs.

# %%
def get_all_url(page):
    hist = []
    while '<a href="' in page:
        if page.find('<a href="') == -1: 
            break
        else:
            start = page.find('<a href="') + len('<a href="')
            end = page.find('"', start)
            url = page[start:end]
            page = page[end:]
            hist.append(url)
    print(hist)
    
get_all_url(page)
# Out:
# ['https://websmart.smccd.edu', 'https://smccd.instructure.com/', 'https://my.smccd.edu', 'https://smccd.edu/portal', 'https://webschedule.smccd.edu', 'https://collegeofsanmateo.edu', 'https://canadacollege.edu', 'https://skylinecollege.edu']

# %% [markdown]
# # requests module

# %% [markdown]
# The requests module allows you to send HTTP requests using Python.
# The HTTP request returns a Response Object with all the response data (content, encoding, status, etc).

# %%
import requests

# %%
#here is an example 
url = 'https://webschedule.smccd.edu/course/202208/97582'
resp=requests.get(url)

# %%
print(resp.text)
# Out:
# <!DOCTYPE html>
# <html xml:lang="en" lang="en" xmlns="http://www.w3.org/1999/xhtml">
#
# <head>
#          <title>WebSchedule - SMCCD</title>
#     <link rel="icon" type="image/x-icon" href="https://webschedule.smccd.edu/favicon.ico" />
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta http-equiv="content-type" content="text/html; charset=utf-8"/>
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#     <link href="//fonts.googleapis.com/css?family=Open+Sans:300,400,600,700|Lora" rel="stylesheet" type="text/css">
#     <link href="https://webschedule.smccd.edu/css/smcccd-bootstrap.css" rel="stylesheet">
#     <link href="https://webschedule.smccd.edu/css/smcccd-theme.css" rel="stylesheet">
#     <link href="//cdnjs.cloudflare.com/ajax/libs/font-awesome/4.1.0/css/font-awesome.min.css" rel="stylesheet">
#     <link href='https://webschedule.smccd.edu/css/style.css' rel='stylesheet' type='text/css'>
# ...

# %% [markdown]
# 6) Write a function num_of_urls. This function must return number of URLs of the page.

# %%
def num_of_urls(url):
    page = requests.get(url)
    page = page.text
    hist = []
    while '<a href="' in page:
        if page.find('<a href="') == -1: 
            break
        else:
            start = page.find('<a href="') + len('<a href="')
            end = page.find('"', start)
            url = page[start:end]
            page = page[end:]
            hist.append(url)
    print(len(hist))

num_of_urls(url)
# Out:
# 46
